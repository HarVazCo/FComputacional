# %%
import sys 
sys.path.append('/home/haroldvaz/computacional/lib/python3.8/site-packages')

# %%
import numpy as np

# %%
x0 = 0.5
x = 0

def fun(x):
    return 2-np.exp(-x)

for i in range(10):
    print(x0)
    x = fun(x0)
    x0 = x
# Out:
# 0.5
# 1.3934693402873666
# 1.751787325113973
# 1.8265363696849992
# 1.8390298555971287
# 1.841028423293983
# 1.8413458214753817
# 1.8413961700324237
# 1.8414041553053788
# 1.8414054217314317

# %% [markdown]
# $M = \mu \tanh \left(\dfrac{JM}{\kappa_B T}\right)$
#
# $m = \tanh \left(\dfrac{Cm}{T}\right)$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x):
    return x**3 + 7

# %%
dx = 0.00001
xn = -5
xp = 5

for i in range(1000000):
    xr = 0.5 *( xn + xp)
    if f(xr)< 0:
        xn = xn + dx
    if f(xr)> 0:
        xp = xp-dx

print(f(xr),xr)
# Out:
# -4.190533662118412e-05 -1.9129350000040646

# %%
plt.plot(X,f(X))
plt.scatter(xr,f(xr),c='orange')
plt.axhline(y = 0.0, xmin = 0.0, color = 'black');

# %%
np.bisec?
# Out:
# Object `np.bisec` not found.
