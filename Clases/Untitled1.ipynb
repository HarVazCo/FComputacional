# %% [markdown]
# ### Método de Euler
#
# $y_{n+1} = y_n + f(x,y)$
#
# $x_{n+1} = x_n + f(x)\Delta x$
#
# $t_{n+1} = t_n + \Delta t$

# %%
import sys 
sys.path.append('/home/haroldvaz/computacional/lib/python3.8/site-packages')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x,t):
    return -x**3 + np.sin(t)

a = 0.0
b = 10.0
N = 1000
h = (b-a)/N
x = 0.0

tpoints = np.arange(a,b,h)
xpoints = []

for t in tpoints:
    xpoints.append(x)
    x += h*f(x,t)

plt.plot(tpoints,xpoints)

# %%
def f(x,t):
    return -x**3 + np.sin(t)

a = 0.0
b = 10.0
N = 100
h = (b-a)/N
x = 0.0

T = np.arange(a,b,h)
X = []

for t in T:
    X.append(x)
    k1 = h*f(x,t)
    x += h*f(x+0.5*k1, t+0.5*h)

# %%
plt.plot(tpoints,xpoints);
